# %% [markdown]
# # ***Rukmini Bugga***

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns
from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# ## Import Data

# %%
data = pd.read_csv("SampleSuperstore.csv")
data.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %% [markdown]
# ## EDA-Exploratory Data Analytics

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.drop_duplicates(keep = "first",inplace = True)
data.shape
# Out:
# (9977, 13)

# %% [markdown]
# ## Heatmap (correlation of features)

# %%
print(data.corr())
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %%
corr = data.corr()
sns.heatmap(corr,annot=True)

# %% [markdown]
# ## Statistical Analysis of Data

# %%
data.groupby('Ship Mode').mean()
# Out:
#                  Postal Code       Sales  Quantity  Discount     Profit
# Ship Mode
# First Class     54751.119063  228.614490  3.702017  0.164587  31.850134
# Same Day        57468.581181  236.755950  3.608856  0.152675  29.283924
# Second Class    55601.554297  236.323750  3.817808  0.138626  29.565956
# Standard Class  54902.907809  227.928858  3.821327  0.160222  27.534715

# %%
data.groupby('State').mean()
# Out:
#                        Postal Code        Sales  Quantity  Discount      Profit
# State
# Alabama               35994.573770   319.846557  4.196721  0.000000   94.865989
# Arizona               85277.348214   157.508933  3.848214  0.303571  -15.303235
# Arkansas              72321.816667   194.635500  4.000000  0.000000   66.811452
# California            92142.342184   229.246629  3.832164  0.072946   38.241878
# Colorado              80295.758242   176.418231  3.807692  0.316484  -35.867351
# Connecticut            6475.670732   163.223866  3.426829  0.007317   42.823071
# Delaware              19755.250000   285.948635  3.822917  0.006250  103.930988
# District of Columbia  20016.000000   286.502000  4.000000  0.000000  105.958930
# Florida               33003.198433   233.612815  3.600522  0.299347   -8.875461
# Georgia               30899.347826   266.825217  3.831522  0.000000   88.315453
# Idaho                 83462.333333   208.689810  3.047619  0.085714   39.367767
# Illinois              60719.183299   163.263823  3.751527  0.389206  -25.665275
# Indiana               46923.503356   359.431946  3.879195  0.000000  123.375411
# Iowa                  51256.900000   152.658667  3.733333  0.000000   39.460397
# Kansas                66824.916667   121.429583  3.083333  0.000000   34.851813
# Kentucky              41189.467626   263.250000  3.762590  0.000000   80.573357
# Louisiana             70777.357143   219.453095  3.714286  0.000000   52.288150
# Maine                  4340.625000   158.816250  4.375000  0.000000   56.810775
# Maryland              21016.571429   225.766886  4.000000  0.005714   66.963608
# Massachusetts          1987.370370   212.106919  3.637037  0.015556   50.262975
# Michigan              48456.204724   298.738756  3.712598  0.007087   96.173584
# Minnesota             55418.247191   335.541011  3.719101  0.000000  121.608847
# Mississippi           39189.113208   203.232830  4.169811  0.000000   59.867475
# Missouri              65126.696970   336.441667  3.818182  0.000000   97.518341
# Montana               59491.733333   372.623467  3.733333  0.066667  122.221900
# Nebraska              68121.421053   196.445526  3.578947  0.000000   53.607742
# Nevada                89136.846154   428.951333  4.307692  0.061538   85.045279
# New Hampshire          3475.370370   270.093481  4.703704  0.011111   63.203807
# New Jersey             7753.338462   275.110092  3.492308  0.004615   75.176260
# New Mexico            87609.621622   129.284378  4.081081  0.059459   31.273408
# Machines      55344.939130  1645.553313  3.826087  0.306087   29.432669
# Paper         55515.896983    57.560075  3.785136  0.074908   24.977365
# Phones        53877.587177   371.211534  3.699663  0.154556   50.073938
# Storage       54667.517730   264.590553  3.732861  0.074704   25.152277
# Supplies      55966.094737   245.650200  3.405263  0.076842   -6.258418
# Tables        58331.749216   648.794771  3.890282  0.261285  -55.565771

# %%
data.drop(['Country'] , axis = 1, inplace =True)
data
# Out:
#            Ship Mode    Segment             City  ... Quantity  Discount    Profit
# 0       Second Class   Consumer        Henderson  ...        2      0.00   41.9136
# 1       Second Class   Consumer        Henderson  ...        3      0.00  219.5820
# 2       Second Class  Corporate      Los Angeles  ...        2      0.00    6.8714
# 3     Standard Class   Consumer  Fort Lauderdale  ...        5      0.45 -383.0310
# 4     Standard Class   Consumer  Fort Lauderdale  ...        2      0.20    2.5164
# ...              ...        ...              ...  ...      ...       ...       ...
# 9989    Second Class   Consumer            Miami  ...        3      0.20    4.1028
# 9990  Standard Class   Consumer       Costa Mesa  ...        2      0.00   15.6332
# 9991  Standard Class   Consumer       Costa Mesa  ...        2      0.20   19.3932
# 9992  Standard Class   Consumer       Costa Mesa  ...        4      0.00   13.3200
# 9993    Second Class   Consumer      Westminster  ...        2      0.00   72.9480
#
# [9977 rows x 12 columns]

# %% [markdown]
# ## Graphical Analysis of Data

# %%
sns.countplot(data['Segment'])
plt.show()

# %%
sns.countplot(data['Sales'])
plt.show()

# %%
sns.countplot(data['State'])
plt.show()

# %%
data.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# ## Pair plot Analysis of Data

# %%
sns.pairplot(data, hue = 'Segment')
plt.show()

# %%
plt.figure(figsize = (30,30))
data.groupby("Sub-Category")['Profit',"Sales"].agg(['sum']).plot.bar()
plt.title("Sub-Category Vs Sales/Profit ")
plt.xlabel("Sub-Category")
plt.ylabel("Sales/Profit")
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.countplot(x= "Sub-Category", hue = "State",data = data)
plt.title("Sub-Category Vs state ")
plt.xlabel("Sub-Category")
plt.ylabel("State")
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.countplot(x= "Sub-Category", hue = "Region",data = data)
plt.title("Sub-Category Vs Region ")
plt.xlabel("Sub-Category")
plt.ylabel("Region")
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.countplot(x= "Sub-Category", hue = "Ship Mode",data = data)
plt.title("Sub-Category Vs Ship mode ")
plt.xlabel("Sub-Category")
plt.ylabel("Ship Mode")
plt.show()

# %%
plt.figure(1)
plt.subplot(221)
data['Category'].value_counts().plot.bar(figsize = (20,10),color = 'red', title = 'Category')
plt.subplot(222)
data['Segment'].value_counts().plot.bar(color = 'blue' , title = 'Segment')
plt.subplot(223)
data['Ship Mode'].value_counts().plot.bar(color = 'green',title = 'Ship Mode')
plt.subplot(224)
data['Region'].value_counts().plot.bar(color = 'pink',title = 'Region')
plt.show()

# %%
plt.figure(figsize = (15,10))
data["Sub-Category"].value_counts().plot.pie(autopct = "%1.if%%")

# %%
plt.figure(figsize = (15,10))
data["Ship Mode"].value_counts().plot.pie(autopct = "%1.if%%")

# %%
plt.figure(figsize = (15,10))
data["Region"].value_counts().plot.pie(autopct = "%1.if%%")

# %%
plt.figure(figsize = (15,10))
data["State"].value_counts().plot.pie(autopct = "%1.if%%")

# %%
plt.figure(figsize = (15,10))
data["Segment"].value_counts().plot.pie(autopct = "%1.if%%")

# %% [markdown]
# ## Heatmap

# %%
data1 = data[['City','Category', 'State','Sales','Profit']]
heatmap1_data = pd.pivot_table(data1,values='Sales', index=["City"], columns='Category')

# %%
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap1_data, cmap="BuGn")

# %%
heatmap2_data = pd.pivot_table(data1,values='Sales', index=["State"], columns='Category')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap2_data, cmap="BuGn")

# %%
heatmap3_data = pd.pivot_table(data1,values='Profit', index=["State"], columns='Category')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap3_data, cmap="BuGn")

# %%
heatmap4_data = pd.pivot_table(data1,values='Profit', index=["City"], columns='Category')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap4_data, cmap="BuGn")

# %%
heatmap6_data = pd.pivot_table(data,values='Profit', index=["State"], columns='Segment')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap6_data, cmap="BuGn")

# %%
sns.scatterplot("Sales","Profit",data = data)
plt.title("Sales Vs Profit ")
plt.xlabel('Sales')
plt.ylabel("Profit")
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.scatterplot("State","Sales",data = data)
plt.title("Sales Vs State ")
plt.ylabel('Sales')
plt.xlabel("State")
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.scatterplot("Ship Mode","Sales",data = data)
plt.title("Sales Vs Ship Mode ")
plt.ylabel('Sales')
plt.xlabel("Ship Mode")
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.scatterplot("Sub-Category","Sales",data = data)
plt.title("Sales Vs Sub-Category ")
plt.ylabel('Sales')
plt.xlabel("Sub-Category")
plt.show()

# %%
pd.crosstab(data["Quantity"],data["Category"],data["Profit"],aggfunc = 'sum').plot(kind = 'bar', stacked = True , )

# %%
sns.catplot(x = "Sub-Category", y = "Profit", data =data, color= "green",height = 4, aspect = 4 )

# %%
sns.catplot(x = "Sub-Category", y = "Profit", data =data, color= "green",height = 4, aspect = 4 , kind = "violin")

# %%
sns.catplot(x = "Sub-Category", y = "Profit", data =data, color= "green",height = 4, aspect = 4 , kind = "bar")

# %%
sns.catplot(x = "Sub-Category", y = "Profit", data =data, color= "green",height = 4, aspect = 4 , kind = "boxen")

# %%
data.plot(kind = 'scatter',x ='Quantity', y = 'Profit', figsize = (12,6), color = 'orange')
